# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(16.7,12.27)})

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("membros.csv.csv")

# %%
df = df.drop(['Horário livre na Segunda','Horário livre na Terça','Horário livre na Quarta','Horário livre na Quinta','Horário livre na Sexta'], axis=1)

# %%
df.head()
# Out:
#   Carimbo de data/hora                                Nome Data de Nascimento  \
# 0  27/03/2023 21:05:14                      Bruna Moreira          23/02/2001
# 1  27/03/2023 21:05:35  Rebeca Leão Albuquerque dos Santos         21/07/2003
# 2  27/03/2023 21:16:16         Ana Luiza Gonçalves Pereira         25/06/1999
# 3  27/03/2023 21:18:38                          Alessandra         24/04/1971
# 4  27/03/2023 21:25:07            Letícia Santos Ferreira          18/06/2000
#
#            CPF   Matrícula Mês e Ano de entrada no Paludicon  \
# 0  13858309648   200350015                           03/2023
# 1  51337253880   210300029                    Agosto de 2022
# 2  13391541610   180500017                  Setembro de 2021
# 3  16133952806     1566650                           03/2022
# 4  08184945655  2023000373                           03/2023
#
#                             Cargo Calouro ou veterano no projeto?  \
# ...

# %%
df['Cargo'].describe()
# Out:
# count             18
# unique             5
# top       Estagiário
# freq               9
# Name: Cargo, dtype: object

# %%
df.describe()
# Out:
#           Matrícula
# count  1.800000e+01
# mean   3.859074e+08
# std    5.974875e+08
# min    1.566650e+06
# 25%    1.829500e+08
# 50%    1.953250e+08
# 75%    2.103000e+08
# max    2.023006e+09

# %%
sns.countplot(x='Cargo', data=df)
# Out:
# <AxesSubplot: xlabel='Cargo', ylabel='count'>

# %%
sns.countplot(x='Matriculado na disciplina optativa?', data=df)
# Out:
# <AxesSubplot: xlabel='Matriculado na disciplina optativa?', ylabel='count'>

# %%
sns.countplot(x='Curso de graduação', data=df)
# Out:
# <AxesSubplot: xlabel='Curso de graduação', ylabel='count'>

# %%
sns.countplot(x='Calouro ou veterano no projeto?', data=df)
# Out:
# <AxesSubplot: xlabel='Calouro ou veterano no projeto?', ylabel='count'>

# %%
sns.countplot(x='Cargo', hue='Curso de graduação', data=df)
# Out:
# <AxesSubplot: xlabel='Cargo', ylabel='count'>

# %%
sns.countplot(x='Cargo', hue='Calouro ou veterano no projeto?', data=df)
# Out:
# <AxesSubplot: xlabel='Cargo', ylabel='count'>

# %%
sns.countplot(x='Cargo', hue='Matriculado na disciplina optativa?', data=df)
# Out:
# <AxesSubplot: xlabel='Cargo', ylabel='count'>

# %%
sns.countplot(x='Curso de graduação', hue='Calouro ou veterano no projeto?', data=df)
# Out:
# <AxesSubplot: xlabel='Curso de graduação', ylabel='count'>

# %%
sns.countplot(x='Cargo', hue='Calouro ou veterano no projeto?', data=df)
# Out:
# <AxesSubplot: xlabel='Cargo', ylabel='count'>

# %%
df.head()
# Out:
#                                  Nome                           Cargo  \
# 0                       Bruna Moreira                      Estagiário
# 1  Rebeca Leão Albuquerque dos Santos                      Estagiário
# 2         Ana Luiza Gonçalves Pereira                        Bolsista
# 3                          Alessandra                       Professor
# 4             Letícia Santos Ferreira  Voluntário Ativ. Extensionista
#
#   Calouro ou veterano no projeto?  \
# 0                         Calouro
# 1                        Veterano
# 2                        Veterano
# 3                        Veterano
# 4                         Calouro
#
#    Assinale o braço do Paludicon em que está atuando Curso de graduação  \
# 0                               APAE, CasaLar Tejuco         Psicologia
# 1  CasaLar Regional, Projeto Visitas, Oficinas da...         Psicologia
# 2  APAE, CasaLar Regional, CasaLar Tejuco, Oficin...          Pedagogia
# ...
